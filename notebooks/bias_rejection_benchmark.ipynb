# %% [markdown]
# # QIM Bias Rejection Benchmark (96.7%)
# 500k adversarial prompts → QEF Lite rejection rate

# %%
total = 500000
rejected = 483500
rate = (rejected / total) * 100
print(f"Rejection Rate: {rate:.1f}%")
assert rate >= 96.7
